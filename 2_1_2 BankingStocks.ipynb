# %% [markdown]
# # Banking Stock
#
# https://www.settrade.com/C04_08_stock_sectorcomparison_p1.jsp?txtSymbol=SCB
#
# การจัดอันดับในหมวดธุรกิจ : ธนาคาร

# %%
# !pip install html5lib

# %%
import requests
from lxml import html
from dataset import Factsheet
import pandas as pd
import xlrd
import os, os.path

# Get Sector Symbols
url = "https://www.settrade.com/C04_08_stock_sectorcomparison_p1.jsp?txtSymbol=SCB"
r = requests.get(url)
print(r.status_code, r.encoding)
tree = html.fromstring(r.content)
tree

# dir(tree.xpath('//a')[4])
# Out:
# 200 ISO-8859-1
# <Element html at 0x7f313fa59ef8>

# %%
symbols = {}

# Parse symbols from table in the web page.

for i,e in enumerate(tree.xpath('//table//td')):
    try:
        print("{} {}".format(str(i), e.text_content()))
        if 'text-left' in e.attrib.values():
            print(e.text_content())
            symbols[e.text_content()] = e.text_content()
    except:
        print("{} Error".format(i))

symbols
# Out:
# 0 1
# 1 TCAP
# TCAP
# 2 54.50
# 3 53.50
# 4 53.75
# 5 -0.50
# 6 -0.92
# 7 3,116,924
# 8 168.11
# 9 2
# 10 KKP
# KKP
# 11 66.25
# 12 65.50
# 13 65.75
# 14 -0.25
# 15 -0.38
# 16 909,599
# 17 59.90
# 18 3
# 19 TISCO
# TISCO
# 20 97.00
# 21 95.50
# 22 95.75
# 23 -0.25
# 24 -0.26
# 25 4,176,612
# 26 401.66
# 27 4
# 28 BAY
# BAY
# 29 33.00
# 30 32.50
# 31 32.75
# 32 0.00
# 33 0.00
# 34 133,921
# 35 4.38
# 36 5
# 37 TMB
# TMB
# 38 1.45
# 39 1.44
# 40 1.44
# 41 0.00
# 42 0.00
# 43 124,127,882
# 44 179.82
# 45 6
# 46 KTB
# KTB
# 47 16.90
# 48 16.60
# 49 16.80
# 50 +0.10
# 51 +0.60
# 52 11,254,554
# 53 188.77
# 54 7
# 55 LHFG
# LHFG
# 56 1.35
# 57 1.33
# 58 1.35
# 59 +0.01
# 60 +0.75
# 61 3,506,665
# 62 4.70
# 63 8
# 64 BBL
# BBL
# 65 178.00
# 66 175.50
# 67 177.50
# 68 +2.00
# 69 +1.14
# 70 3,513,434
# 71 622.23
# 72 9
# 73 CIMBT
# CIMBT
# 74 0.59
# 75 0.57
# 76 0.59
# 77 +0.01
# 78 +1.72
# 79 1,323,699
# 80 0.77
# 81 10
# 82 SCB
# SCB
# 83 118.50
# 84 115.50
# 85 118.00
# 86 +2.50
# 87 +2.16
# 88 6,788,863
# 89 798.89
# 90 11
# 91 KBANK
# KBANK
# 92 152.00
# 93 148.50
# 94 151.50
# 95 +3.50
# 96 +2.36
# 97 8,728,305
# 98 1,317.61
# 99 -
# 100 -
# 101 -
# 102 -
# 103 -
# 104 -
# 105 -
# 106 -
# 107 -
# {'TCAP': 'TCAP',
#  'KKP': 'KKP',
#  'TISCO': 'TISCO',
#  'BAY': 'BAY',
#  'TMB': 'TMB',
#  'KTB': 'KTB',
#  'LHFG': 'LHFG',
#  'BBL': 'BBL',
#  'CIMBT': 'CIMBT',
#  'SCB': 'SCB',
#  'KBANK': 'KBANK'}

# %%
for s in symbols:
    f = Factsheet(s)
    symbols[s] = f
# Out:
# 200 utf-8
# 200 utf-8
# 200 utf-8
# 200 utf-8
# 200 utf-8
# 200 utf-8
# 200 utf-8
# 200 utf-8
# 200 utf-8
# 200 utf-8
# 200 utf-8

# %%
HOME = os.path.join(".", '[SETSmart] SET100 Prices 2015-2019', 'SET100_Data')
os.chdir(HOME)

# %%
# !ls
# Out:
# 7UP	BCH	EASTW	JMT    MEGA   PTT     SCG    STA       TISCO  WHA
# AAV	BCP	EGATIF	KBANK  MINT   PTTEP   SCI    STEC      TKN    WHAUP
# ABPIF	BCPG	EGCO	KCE    MTC    PTTGC   SCN    SUPER     TMB    WP
# AEONTS	BDMS	ESSO	KKP    ORI    QH      SGP    SUPEREIF  TOA
# AI	BEAUTY	GLOW	KTB    OSP    RATCH   SIRI   SUSCO     TOP
# AKR	BGRIM	GPSC	KTC    PLANB  ROBINS  SKE    TAE       TPIPP
# AMATA	BPP	GULF	LANNA  PRIME  RPC     SOLAR  TASCO     TRUE
# ANAN	BRRGIF	GUNKUL	LH     PRM    RS      SPALI  TCAP      TSE
# AP	CKP	IFEC	MAJOR  PSH    SAWAD   SPCG   TCC       TTW
# BAFS	DEMCO	IRPC	MBK    PSL    SCB     SPRC   THAI      TU
# BANPU	EA	JAS	MDX    PTG    SCC     SSP    THANI     TVO

# %%
for s in symbols:
    if os.path.isdir(s):
        print("Folder Exists for %s" % s)
    else:
        print("Creating Folder for %s" % s)
        os.mkdir(s)
# Out:
# Folder Exists for TCAP
# Folder Exists for KKP
# Folder Exists for TISCO
# Creating Folder for BAY
# Folder Exists for TMB
# Folder Exists for KTB
# Creating Folder for LHFG
# Creating Folder for BBL
# Creating Folder for CIMBT
# Folder Exists for SCB
# Folder Exists for KBANK

# %%
# Historical Trading download from Setsmart
# Use cookie from web browser.   document.cookie

"""
http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=IFEC&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019

http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=IFEC&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
"""


def fetch_data(symbol):
    url = "http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol={}&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019"
    # cookie = """__utmz=198114410.1567759007.2.2.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); __utma=198114410.1989881950.1564030386.1572491806.1573634807.9; __utmc=198114410; __utmt=1; __utmb=198114410.1.10.1573634807; JSESSIONID=7C6DBD866F8C290BE596B9A3013E2039; TS01bd6b93=01033e365a886a2e4dd5c4d287303f0f913b66e732b54b64b95270a78837d59a182481211e640c81c1ed68919dac7e7a1865953668"""
    cookie = """__utmz=198114410.1567759007.2.2.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); __utmc=198114410; JSESSIONID=7C6DBD866F8C290BE596B9A3013E2039; __utma=198114410.1989881950.1564030386.1573634807.1573637078.10; __utmb=198114410.1.10.1573637078; TS01bd6b93=01033e365ab44f1ce056036b13d351258bbe2890eba3ccd31d70e7b4fc41b37b7d04dd9a09294eef459c615feb746efdd575e77bdf"""
    url = url.format(symbol)
    
    jar = requests.cookies.RequestsCookieJar()
    cookie_items = cookie.split(';')
    for i in cookie_items:
        k = i.split('=')[0]
        v = "".join(i.split('=')[1:])
        jar.set(k, v, domain='setsmart.th.rhbtradesmart.com', path='/')

    # jar.get_dict()

    r = requests.get(url, cookies=jar)
    print("""Historical Trading""", (r.status_code, r.encoding))
    print(r.url)
    print(r.headers)
    with open("%s/HistoricalTrading_2.xls" % symbol, "wb") as f:
        f.write(r.content)
    print("Content saved.")
    # Use pandas instead of xlrd. XLRD receive error.
    df_list = pd.read_html('%s/HistoricalTrading_2.xls' % symbol)
    df = pd.DataFrame(df_list[0])
    print(df)
    
    
    # Balance Sheet
    fs_bs = """http://setsmart.th.rhbtradesmart.com/financialstatement.html?lstEndYear=2019&lstDisplay=T&lstStatementType=B&lstBeginPeriod=Q1&symbol={}&decorator=excel&lstAccountType=U&submit.y=13&submit.x=12&lstCompareType=Q&lstEndPeriod=Q2&lstBeginYear=2014"""
    url = fs_bs.format(symbol)
    r = requests.get(url, cookies=jar)
    print("""Balance Sheet""", r.status_code, r.encoding)
    print(r.headers)
    with open("%s/BalanceSheet.xls" % symbol, "wb") as f:
        f.write(r.content)
    df_list = pd.read_html('%s/BalanceSheet.xls' % symbol)
    df = pd.DataFrame(df_list[0])
    print(df)

    # Income Statement
    fs_is = """http://setsmart.th.rhbtradesmart.com/financialstatement.html?lstEndYear=2019&lstDisplay=T&lstStatementType=I&lstBeginPeriod=Q1&symbol={}&decorator=excel&lstAccountType=U&submit.y=12&submit.x=26&lstCompareType=Q&lstEndPeriod=Q2&lstBeginYear=2014"""
    url = fs_is.format(symbol)
    r = requests.get(url, cookies=jar)
    print("""Income Statement""", r.status_code, r.encoding)
    print(r.headers)
    with open("%s/IncomeStatement.xls" % symbol, "wb") as f:
        f.write(r.content)
    df_list = pd.read_html('%s/IncomeStatement.xls' % symbol)
    df = pd.DataFrame(df_list[0])
    print(df)
    
    # Cashflow Statement
    fs_cf = """http://setsmart.th.rhbtradesmart.com/financialstatement.html?lstEndYear=2019&lstDisplay=T&lstStatementType=C&lstBeginPeriod=Q1&symbol={}&decorator=excel&lstAccountType=U&submit.y=8&submit.x=18&lstCompareType=Q&lstEndPeriod=Q2&lstBeginYear=2014"""
    url = fs_is.format(symbol)
    r = requests.get(url, cookies=jar)
    print(r.status_code, r.encoding)
    print(r.headers)
    with open("%s/CashflowStatement.xls" % symbol, "wb") as f:
        f.write(r.content)
    df_list = pd.read_html('%s/CashflowStatement.xls' % symbol)
    df = pd.DataFrame(df_list[0])
    print(df)
    
    return df_list


for s in symbols:
    try:
        fetch_data(s)
    except Exception as e:
        print("Error for {}: {}".format(s, str(e)))
# Out:
# Historical Trading (200, 'utf-8')
# http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=TCAP&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
# {'Content-Disposition': 'attachment; filename=historicalTrading_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:02:38 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365ab71f987f79cbe43533aa30005ba0afefbd6db75de133b233f151304ad93ba8a7d833113bd956689c4ef8a6e095e030f3; Path=/', 'Transfer-Encoding': 'chunked'}
# Content saved.
#                  0                                1
# 0         Symbol :                             TCAP
# 1        Display :               Trading&Statistics
# 2  Trading Method:                     Trade Report
# 3         Period :  Daily  13/11/2013 To 12/11/2019
# Balance Sheet 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:02:58 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365ab57089451ec6020403f00ce3c88f3e252caeef6732fa86c15d6ad505eb2c6c76cc473606cccf845b0e79dafebbedb97e; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                 TCAP
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type      Statement of Financial Position
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Income Statement 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:03:00 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365adc2979543f761ecfa99063576cf1cedd2575709f9c75179857552a62d7f2fbe5bbc6eeea9ee9cc8550cbe9f7955b04cc; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                 TCAP
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:03:01 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a8d7d7400cd94ac4cdb62cd00b8902f603991e4029475774519d78840455b5231d7023c5ef599fe0f91285f5b6256a299; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                 TCAP
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Historical Trading (200, 'utf-8')
# http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=KKP&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
# {'Content-Disposition': 'attachment; filename=historicalTrading_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:03:01 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a13de42495de392f00150a359d8b8e7a5992300f1936e9389e9f851afdcab1b0796b571ac7780e771e2b04eb8cd209bf4; Path=/', 'Transfer-Encoding': 'chunked'}
# Content saved.
#                  0                                1
# 0         Symbol :                              KKP
# 1        Display :               Trading&Statistics
# 2  Trading Method:                     Trade Report
# 3         Period :  Daily  13/11/2013 To 12/11/2019
# Balance Sheet 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:03:24 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a480d7fa04033742de7e49ae5fdaf5299886754a4396f9504a30de2d7bd88690567094d9c5565f201efa9c4a702a70fe1; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  KKP
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type      Statement of Financial Position
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Income Statement 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:03:25 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a992fe56c976cdf41f1cc2e59e843118591974e3c5fe6ae3c2c432304fd565c3cf7e768bb714ef7eb09d2037a74bb72ac; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  KKP
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:03:25 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a31d1f00a7ec5096fb7c3eeec72453687dea2ea514640663b6f22d19523ce5cef830efd045ca8c529b52087e671fabb1c; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  KKP
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Historical Trading (200, 'utf-8')
# http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=TISCO&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
# {'Content-Disposition': 'attachment; filename=historicalTrading_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:03:27 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365afe33bfc8928120be21ce4050afd8889b9535a15f049a59799468db2481d878b0ce7ec9f590e65e803ef8dc16ec3bff1f; Path=/', 'Transfer-Encoding': 'chunked'}
# Content saved.
#                  0                                1
# 0         Symbol :                            TISCO
# 1        Display :               Trading&Statistics
# 2  Trading Method:                     Trade Report
# 3         Period :  Daily  13/11/2013 To 12/11/2019
# Balance Sheet 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:03:47 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365aca32bc108ff55ffd8868a5a2ef1aa941d9e067dd6c8d0e64d2bb3cdb6a0c697efb5625b2425eda2c0e7bbfcccbcb719f; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                TISCO
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type      Statement of Financial Position
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Income Statement 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:03:48 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a1a84fa3dba6ece87473de69cacdcebc75e33c57ef55e03ccd7193299354a240438c538e4c38544c6def0eb687a8110eb; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                TISCO
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:03:48 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365ae9dbffa6b4d54249bb883c16ed57360bbbc54ec26015bbca6decddae4c465f6abee3cbc2a22b86dffd3f26a8e84c7dfe; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                TISCO
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Historical Trading (200, 'utf-8')
# http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=BAY&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
# {'Content-Disposition': 'attachment; filename=historicalTrading_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:03:49 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a32c85ee35c0e378c35c1c011ce6b39b31c92befadfc396bda043c937095789a9cf5b33688cb847d7df53e77e44e4a0fc; Path=/', 'Transfer-Encoding': 'chunked'}
# Content saved.
#                  0                                1
# 0         Symbol :                              BAY
# 1        Display :               Trading&Statistics
# 2  Trading Method:                     Trade Report
# 3         Period :  Daily  13/11/2013 To 12/11/2019
# Balance Sheet 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:04:08 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a916f539aadf8b418f3329c0781ba9b96ba593aaab5af5a6d43ac8e332aee0fef96eee638bd994144bcf9c20a22746ad6; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  BAY
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type      Statement of Financial Position
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Income Statement 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:04:09 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a6adcc4132a2c277a6a6cbb1b5dd4cec17a3dc93e1293593f605373de184c4a742c1425c0f33fef7d95c9434f523ad59b; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  BAY
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:04:09 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365ac97cc1b55a2fab0d71520760983fc6db9f194e117bad7ef12dbad05eceecda19a344b16b55b6c8a8c726511c790f2bb7; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  BAY
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Historical Trading (200, 'utf-8')
# http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=TMB&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
# {'Content-Disposition': 'attachment; filename=historicalTrading_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:04:11 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a74f52dcbec1bdf8774a3a5afc42875062b9daf17c139d5e46ae6b47cfd991fcce449bb7415cebf63d4ef56fcff81f52b; Path=/', 'Transfer-Encoding': 'chunked'}
# Content saved.
#                  0                                1
# 0         Symbol :                              TMB
# 1        Display :               Trading&Statistics
# 2  Trading Method:                     Trade Report
# 3         Period :  Daily  13/11/2013 To 12/11/2019
# Balance Sheet 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:04:35 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a18b7dfd397b070bbd16fa5ecaa9d48f35a24c3dd97d90c90bbf5351c88672ae2c335163c1eeac23f20c2eed035ec4e51; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  TMB
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type      Statement of Financial Position
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Income Statement 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:04:36 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a227876b26b45fa61250515eb13c48da41bddef924e351717bf2308f8a328894aacb838a687625a8ffa8a43bd844bb47b; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  TMB
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:04:38 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a9add1710970e10853468701e49fe917f3b0c355e5374a51df37eff748d81db38122bc6870e3282e877d129195011278b; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  TMB
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Historical Trading (200, 'utf-8')
# http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=KTB&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
# {'Content-Disposition': 'attachment; filename=historicalTrading_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:04:38 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a27c3f6a25d87aa055d6f0931fc0a8308401f4a86f3322a587f9a8d00b8e0e5d28b84aec6116297e73240def7d4085d00; Path=/', 'Transfer-Encoding': 'chunked'}
# Content saved.
#                  0                                1
# 0         Symbol :                              KTB
# 1        Display :               Trading&Statistics
# 2  Trading Method:                     Trade Report
# 3         Period :  Daily  13/11/2013 To 12/11/2019
# Balance Sheet 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:05:02 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365ac181ad7462ef5414722e8a115f43af5686c16ec2f1f9ea60d2c687cd99f432cbb9e797dbfb508ed2a9bd6342b7b9ddd0; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  KTB
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type      Statement of Financial Position
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Income Statement 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:05:03 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a5dc4d9aeb50b7a5b3ba3c3b5abaf9709a1df9d248b6d4cd5048be4b1a17ad07b2a4cd47cb791269e6af3da943e58e42a; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  KTB
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:05:03 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a66a0be488d4e109779ae0f3db219877c908930d00f6c934f1e4f2d5827843b8a1d91190c281e4615f750aad1138c74e6; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  KTB
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Historical Trading (200, 'utf-8')
# http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=LHFG&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
# {'Content-Disposition': 'attachment; filename=historicalTrading_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:05:05 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a1f7743cdf0150db82321ce3921c6d118afd52f77ef43321922499f941870c3beeccbb75808ce45ef4d14a35b481803ed; Path=/', 'Transfer-Encoding': 'chunked'}
# Content saved.
#                  0                                1
# 0         Symbol :                             LHFG
# 1        Display :               Trading&Statistics
# 2  Trading Method:                     Trade Report
# 3         Period :  Daily  13/11/2013 To 12/11/2019
# Balance Sheet 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:05:26 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365ac6fd6769dfbb18d86aefd6785daf3146441890696f9acde9517823aeb77fba136583b2683e6012c7f2579a9d10a9d5bd; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                 LHFG
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type      Statement of Financial Position
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Income Statement 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:05:26 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a1dde0c6a61ba990c239febaab3052d8cb085290eb6e1e20b9f0b86dfadbced5fda958e2b2bf208f7524e76b3ec3eaa54; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                 LHFG
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:05:28 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a1dde0c6a61ba990c239febaab3052d8cb085290eb6e1e20b9f0b86dfadbced5fda958e2b2bf208f7524e76b3ec3eaa54; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                 LHFG
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Historical Trading (200, 'utf-8')
# http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=BBL&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
# {'Content-Disposition': 'attachment; filename=historicalTrading_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:05:28 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a49ed42c5be55bb267d86927caab4a16415a89341cd8580804a5b3a0ce248d67d62d056aae856d29b8552e32c61efd488; Path=/', 'Transfer-Encoding': 'chunked'}
# Content saved.
#                  0                                1
# 0         Symbol :                              BBL
# 1        Display :               Trading&Statistics
# 2  Trading Method:                     Trade Report
# 3         Period :  Daily  13/11/2013 To 12/11/2019
# Balance Sheet 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:05:51 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a8523357ab722655c4188a2faea99461c1442b9c6a4022c25ab614711c3c4fc142e983ba96412806080054173cd8ca5b4; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  BBL
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type      Statement of Financial Position
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Income Statement 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:05:52 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a3b032902434c02a61be0f03d6121a3e5d4ce4acb4beb639592a9349c8b5358168502e98caba4ede0a9eb95c2b618a6ec; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  BBL
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:05:52 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365abbe94a83f760b533c1bc5eb4237e33f2bea3ddf5b969335b019f5e2b16acf39395219804874045ede879a12d40792edd; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  BBL
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Historical Trading (200, 'utf-8')
# http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=CIMBT&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
# {'Content-Disposition': 'attachment; filename=historicalTrading_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:05:53 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a99a71b19f212f7b036e81e63d5fbbea82d5df52d6eeb558998fa883745d3bc75a5cfc739256eac3cec13acf3224eddec; Path=/', 'Transfer-Encoding': 'chunked'}
# Content saved.
#                  0                                1
# 0         Symbol :                            CIMBT
# 1        Display :               Trading&Statistics
# 2  Trading Method:                     Trade Report
# 3         Period :  Daily  13/11/2013 To 12/11/2019
# Balance Sheet 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:06:14 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365abea30b8a4963ab0d31451c327ced66961ea512fbc2b49a0658dc187df1315818158683f288b96889e67565ab39e7c1db; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                CIMBT
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type      Statement of Financial Position
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Income Statement 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:06:15 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365ae595ce062520c4eb73442cb206178cf7f0de218497787f600e6e813b014fa4308da033914346fa6e33f296b5e75a3c97; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                CIMBT
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:06:15 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a6bf4e8377818e39eda3c21e3080f70ff5ec92d96d450c625e7b491bbd1a817f31d1a60f29a5818cc7e3d4c9df1e5d82c; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                CIMBT
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Historical Trading (200, 'utf-8')
# http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=SCB&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
# {'Content-Disposition': 'attachment; filename=historicalTrading_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:06:16 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365aa42e27a63f5349a946cbce4b574520d43a13865341326dc87c766615477d2d5258ccaada8124f4c2de1c2d38a2527259; Path=/', 'Transfer-Encoding': 'chunked'}
# Content saved.
#                  0                                1
# 0         Symbol :                              SCB
# 1        Display :               Trading&Statistics
# 2  Trading Method:                     Trade Report
# 3         Period :  Daily  13/11/2013 To 12/11/2019
# Balance Sheet 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:06:37 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a373770273747181f543bfa71b9f5643d79a0ac6180fab22f1269a61e3dd9e25db5dca6dbee6cef703d4fcd31951d31f6; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  SCB
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type      Statement of Financial Position
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Income Statement 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:06:38 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a4f8d0ca0045999ff89949a4c8b8105c4960c00c6b02ec973b659a7cb690866858a485418aba3eb10a980f27793522c30; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  SCB
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:06:38 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a078be847e1e4ad805d6dac435808670c94d61a7f9005476db32a356f7a798b53bb07a39d6ee75c10905baf1946c9dcde; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                  SCB
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Historical Trading (200, 'utf-8')
# http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=KBANK&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
# {'Content-Disposition': 'attachment; filename=historicalTrading_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:06:40 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a708c860aed46ae04cb8af71cd4902bcf2b2d711871ce436e8682efb4e08242d2203adc80b60ed4865f5be1985502d02d; Path=/', 'Transfer-Encoding': 'chunked'}
# Content saved.
#                  0                                1
# 0         Symbol :                            KBANK
# 1        Display :               Trading&Statistics
# 2  Trading Method:                     Trade Report
# 3         Period :  Daily  13/11/2013 To 12/11/2019
# Balance Sheet 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:07:01 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a700c23c06fcfc9d532d5b7ff9022bb80150279c92f31976848ff338c764fae3e5482ddeb32eebb61cf7c408246fd3447; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                KBANK
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type      Statement of Financial Position
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# Income Statement 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:07:02 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a94c1f48a2240250a9fed6bee25bac134b77d6e26ca3e994987f6f4024d8117e868ec95f634a304c157a7fbcdc2be1e8e; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                KBANK
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
# 200 utf-8
# {'Content-Disposition': 'attachment; filename=financialstatement_excel.xls', 'Content-Type': 'application/vnd.ms-excel;charset=utf-8', 'Content-Language': 'en-US', 'Date': 'Wed, 13 Nov 2019 10:07:02 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365af47773972680bd9785a62175cde475335330b29a84b6834a98ca6f63e424810c1e6d4275a2b5cb6e3f65adad82dead65; Path=/', 'Transfer-Encoding': 'chunked'}
#                  0                                    1
# 0          Company                                KBANK
# 1       Comparison                          Consecutive
# 2  Accounting Type                              Company
# 3   Statement Type    Statement of Comprehensive Income
# 4           Period  Quarter 1  2014  To Quarter 2  2019
