# %% [markdown]
# http://setsmart.th.rhbtradesmart.com/
#
#
# Capture network log for chrome
# https://stackoverflow.com/questions/48921321/capture-downloads-in-the-network-tab-of-google-chrome-developer-tools
#
# chrome://net-export/

# %%
import pandas as pd
import requests

# %%
df = pd.read_csv("SET_symbols.csv", index_col="symbol")
df
# Out:
#        Unnamed: 0 exchange                    industry  \
# symbol
# 7UP           7UP      SET                    ทรัพยากร
# A               A      SET  อสังหาริมทรัพย์และก่อสร้าง
# AAV           AAV      SET                      บริการ
# ABPIF       ABPIF      SET                    ทรัพยากร
# ACC           ACC      SET          สินค้าอุปโภคบริโภค
# ...           ...      ...                         ...
# WP             WP      SET                    ทรัพยากร
# WPH           WPH      SET                      บริการ
# YCI           YCI      SET            สินค้าอุตสาหกรรม
# ZEN           ZEN      SET     เกษตรและอุตสาหกรรมอาหาร
# ZMICO       ZMICO      SET               ธุรกิจการเงิน
#
#                               sector  \
# symbol
# 7UP            พลังงานและสาธารณูปโภค
# A               พัฒนาอสังหาริมทรัพย์
# AAV               ขนส่งและโลจิสติกส์
# ABPIF          พลังงานและสาธารณูปโภค
# ACC     ของใช้ในครัวเรือนและสำนักงาน
# ...                              ...
# WP             พลังงานและสาธารณูปโภค
# WPH                         การแพทย์
# YCI            ปิโตรเคมีและเคมีภัณฑ์
# ZEN              อาหารและเครื่องดื่ม
# ZMICO           เงินทุนและหลักทรัพย์
#
#                                                      name
# symbol
# 7UP     บริษัท เซเว่น ยูทิลิตี้ส์ แอนด์ พาวเวอร์ จำกัด...
# A                บริษัท อารียา พรอพเพอร์ตี้ จำกัด (มหาชน)
# AAV                บริษัท เอเชีย เอวิเอชั่น จำกัด (มหาชน)
# ABPIF   กองทุนรวมโครงสร้างพื้นฐานโรงไฟฟ้า อมตะ บี.กริม...
# ACC     บริษัท แอดวานซ์ คอนเนคชั่น คอร์ปอเรชั่น จำกัด ...
# ...                                                   ...
# WP            บริษัท ดับบลิวพี เอ็นเนอร์ยี่ จำกัด (มหาชน)
# WPH          บริษัท โรงพยาบาลวัฒนแพทย์ ตรัง จำกัด (มหาชน)
# YCI                            บริษัท ยงไทย จำกัด (มหาชน)
# ZEN          บริษัท เซ็น คอร์ปอเรชั่น กรุ๊ป จำกัด (มหาชน)
# ZMICO              บริษัทหลักทรัพย์ ซีมิโก้ จำกัด (มหาชน)
#
# [573 rows x 5 columns]

# %%
# Historical Trading download from Setsmart
# Use cookie from web browser.   document.cookie

"""
http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=IFEC&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019

http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=IFEC&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
"""

def download_setsmart_data(symbol, urlTemplate, resultFilename, description, jar):
    url = urlTemplate.format(symbol)
    r = requests.get(url, cookies=jar)
    print(description, (r.status_code, r.encoding))
    print(r.url)
    print(r.headers)
    with open("%s_%s" % (symbol, resultFilename), "wb") as f:
        f.write(r.content)
    print("Content saved.")
    # Use pandas instead of xlrd. XLRD receive error.
    df_list = pd.read_html("%s_%s" % (symbol, resultFilename))
    df = pd.DataFrame(df_list[0])
    print(df)
    return df_list

def fetch_data(symbol):
    url = "http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol={}&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019"
    # cookie = """__utmz=198114410.1567759007.2.2.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); __utma=198114410.1989881950.1564030386.1572491806.1573634807.9; __utmc=198114410; __utmt=1; __utmb=198114410.1.10.1573634807; JSESSIONID=7C6DBD866F8C290BE596B9A3013E2039; TS01bd6b93=01033e365a886a2e4dd5c4d287303f0f913b66e732b54b64b95270a78837d59a182481211e640c81c1ed68919dac7e7a1865953668"""
    # cookie = """__utmz=198114410.1567759007.2.2.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); __utmc=198114410; JSESSIONID=7C6DBD866F8C290BE596B9A3013E2039; __utma=198114410.1989881950.1564030386.1573634807.1573637078.10; __utmb=198114410.1.10.1573637078; TS01bd6b93=01033e365ab44f1ce056036b13d351258bbe2890eba3ccd31d70e7b4fc41b37b7d04dd9a09294eef459c615feb746efdd575e77bdf"""
    cookie = """__cfduid=dacb4349a8dc5a64ca19024e4ee54c6601564030383; __utmz=198114410.1567759007.2.2.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); __utmc=198114410; TS01bd6b93_77=0898ee9a1fab28007fba126e30587da1207dcf5a57074c06d3b2ff4dace9eeb1e368dd1bb2623881830f6da449c5b10f08b6cccc53823800b27b432b2cd78abc88fd77533faf533fb975aed9e9edaeda96a8e31ae79ee9930142105caa5008b8aa516229592db117bc8a59c02eba07c1; JSESSIONID=BC76F2F0314D1D28F81B3CB4B4020578; TS01bd6b93=01033e365aabd9b79ddda11648a9609035a8bd3e1a53d3baa9fe9a0d0ba22b4602abe82ff333f1ade3ca2ff53a2c05921d9c68db6e; __utma=198114410.1989881950.1564030386.1573637078.1573870379.11; __utmt=1; __utmb=198114410.1.10.1573870379"""
    url = url.format(symbol)
    
    jar = requests.cookies.RequestsCookieJar()
    cookie_items = cookie.split(';')
    for i in cookie_items:
        k = i.split('=')[0]
        v = "".join(i.split('=')[1:])
        jar.set(k, v, domain='setsmart.th.rhbtradesmart.com', path='/')

    # jar.get_dict()
    
    # Auto Matching
    description = """Historical Trading AOM"""
    urlTemplate = """http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol={}&lstMethod=AOM&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019"""
    resultFilename = """HistoricalTrading_AOM.xls"""
    df = download_setsmart_data(symbol, urlTemplate, resultFilename, description, jar)
    
    # Trade Report
    description = """Historical Trading TR"""
    urlTemplate = """http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol={}&lstMethod=TR&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019"""
    resultFilename = """HistoricalTrading_TR.xls"""
    df = download_setsmart_data(symbol, urlTemplate, resultFilename, description, jar)    

    return df
    
def download_financial_statements():
    # Balance Sheet
    fs_bs = """http://setsmart.th.rhbtradesmart.com/financialstatement.html?lstEndYear=2019&lstDisplay=T&lstStatementType=B&lstBeginPeriod=Q1&symbol={}&decorator=excel&lstAccountType=U&submit.y=13&submit.x=12&lstCompareType=Q&lstEndPeriod=Q2&lstBeginYear=2014"""
    url = fs_bs.format(symbol)
    r = requests.get(url, cookies=jar)
    print("""Balance Sheet""", r.status_code, r.encoding)
    print(r.headers)
    with open("%s/BalanceSheet.xls" % symbol, "wb") as f:
        f.write(r.content)
    df_list = pd.read_html('%s/BalanceSheet.xls' % symbol)
    df = pd.DataFrame(df_list[0])
    print(df)

    # Income Statement
    fs_is = """http://setsmart.th.rhbtradesmart.com/financialstatement.html?lstEndYear=2019&lstDisplay=T&lstStatementType=I&lstBeginPeriod=Q1&symbol={}&decorator=excel&lstAccountType=U&submit.y=12&submit.x=26&lstCompareType=Q&lstEndPeriod=Q2&lstBeginYear=2014"""
    url = fs_is.format(symbol)
    r = requests.get(url, cookies=jar)
    print("""Income Statement""", r.status_code, r.encoding)
    print(r.headers)
    with open("%s/IncomeStatement.xls" % symbol, "wb") as f:
        f.write(r.content)
    df_list = pd.read_html('%s/IncomeStatement.xls' % symbol)
    df = pd.DataFrame(df_list[0])
    print(df)
    
    # Cashflow Statement
    fs_cf = """http://setsmart.th.rhbtradesmart.com/financialstatement.html?lstEndYear=2019&lstDisplay=T&lstStatementType=C&lstBeginPeriod=Q1&symbol={}&decorator=excel&lstAccountType=U&submit.y=8&submit.x=18&lstCompareType=Q&lstEndPeriod=Q2&lstBeginYear=2014"""
    url = fs_is.format(symbol)
    r = requests.get(url, cookies=jar)
    print(r.status_code, r.encoding)
    print(r.headers)
    with open("%s/CashflowStatement.xls" % symbol, "wb") as f:
        f.write(r.content)
    df_list = pd.read_html('%s/CashflowStatement.xls' % symbol)
    df = pd.DataFrame(df_list[0])
    print(df)
    
    return df_list

"""
for s in symbols:
    try:
        fetch_data(s)
    except Exception as e:
        print("Error for {}: {}".format(s, str(e)))
"""
# Out:
# '\nfor s in symbols:\n    try:\n        fetch_data(s)\n    except Exception as e:\n        print("Error for {}: {}".format(s, str(e)))\n'

# %%
# Out:
# Historical Trading AOM (404, 'utf-8')
# http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=SCC&lstMethod=AOM&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
# {'Content-Type': 'text/html;charset=utf-8', 'Content-Language': 'en', 'Content-Length': '1096', 'Date': 'Mon, 09 Mar 2020 11:45:40 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365ab18259fa8a7927b13f75262749cf860f512d8943f31e757ce3884e5d7eb0682f6761b13f28151ea54858438bb9ede704; Path=/'}
# Content saved.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-26bc324b5233> in <module>
#       1 # Export
# ----> 2 fetch_data("SCC")
#
# <ipython-input-18-74308a7dec58> in fetch_data(symbol)
#      43     urlTemplate = """http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol={}&lstMethod=AOM&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019"""
#      44     resultFilename = """HistoricalTrading_AOM.xls"""
# ---> 45     df = download_setsmart_data(symbol, urlTemplate, resultFilename, description, jar)
#      46
#      47     # Trade Report
#
# <ipython-input-18-74308a7dec58> in download_setsmart_data(symbol, urlTemplate, resultFilename, description, jar)
#      18     print("Content saved.")
#      19     # Use pandas instead of xlrd. XLRD receive error.
# ---> 20     df_list = pd.read_html("%s_%s" % (symbol, resultFilename))
#      21     df = pd.DataFrame(df_list[0])
#      22     print(df)
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     886     retained = None
#     887     for flav in flavor:
# --> 888         parser = _parser_dispatch(flav)
#     889         p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     890
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/html.py in _parser_dispatch(flavor)
#     833     if flavor in ("bs4", "html5lib"):
#     834         if not _HAS_HTML5LIB:
# --> 835             raise ImportError("html5lib not found, please install it")
#     836         if not _HAS_BS4:
#     837             raise ImportError("BeautifulSoup4 (bs4) not found, please install it")
#
# ImportError: html5lib not found, please install it

# %%
# !pip install html5lib
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: html5lib in /opt/conda/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.7/site-packages (from html5lib) (1.14.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from html5lib) (0.5.1)

# %%
# Export
fetch_data("SCC")
# Out:
# Historical Trading AOM (404, 'utf-8')
# http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol=SCC&lstMethod=AOM&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019
# {'Content-Type': 'text/html;charset=utf-8', 'Content-Language': 'en', 'Content-Length': '1096', 'Date': 'Mon, 09 Mar 2020 11:45:55 GMT', 'Set-Cookie': 'TS01bd6b93=01033e365a1dad8424fbf59d0db2784fe323c4e4ac3321194e1ac0a2d986d3ddd91e61fce73f96063ac6b81252367de1c8298da04f; Path=/'}
# Content saved.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-26bc324b5233> in <module>
#       1 # Export
# ----> 2 fetch_data("SCC")
#
# <ipython-input-18-74308a7dec58> in fetch_data(symbol)
#      43     urlTemplate = """http://setsmart.th.rhbtradesmart.com/historicalTrading.html?lstDisplay=T&symbol={}&lstMethod=AOM&decorator=excel&showBeginDate=13%2F11%2F2013&lstPeriod=D&endDate=12%2F11%2F2019&beginDate=13%2F11%2F2013&quickPeriod=6Y&showEndDate=12%2F11%2F2019"""
#      44     resultFilename = """HistoricalTrading_AOM.xls"""
# ---> 45     df = download_setsmart_data(symbol, urlTemplate, resultFilename, description, jar)
#      46
#      47     # Trade Report
#
# <ipython-input-18-74308a7dec58> in download_setsmart_data(symbol, urlTemplate, resultFilename, description, jar)
#      18     print("Content saved.")
#      19     # Use pandas instead of xlrd. XLRD receive error.
# ---> 20     df_list = pd.read_html("%s_%s" % (symbol, resultFilename))
#      21     df = pd.DataFrame(df_list[0])
#      22     print(df)
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     886     retained = None
#     887     for flav in flavor:
# --> 888         parser = _parser_dispatch(flav)
#     889         p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     890
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/html.py in _parser_dispatch(flavor)
#     833     if flavor in ("bs4", "html5lib"):
#     834         if not _HAS_HTML5LIB:
# --> 835             raise ImportError("html5lib not found, please install it")
#     836         if not _HAS_BS4:
#     837             raise ImportError("BeautifulSoup4 (bs4) not found, please install it")
#
# ImportError: html5lib not found, please install it
